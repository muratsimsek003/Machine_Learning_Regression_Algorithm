# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/drive/MyDrive/DATA_MINING/advertising.csv")

# %%
df.head(10)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   10.6

# %%
X=df[["TV"]]
y=df[["sales"]]

# %%
reg_model=LinearRegression().fit(X,y)

#y_hat=b+w*TV

# %%
reg_model.intercept_
# Out:
# array([7.03259355])

# %%
#theta0=7.03  bias b= 7.03

# %%
reg_model.coef_
# Out:
# array([[0.04753664]])

# %%
# y_hat=7.03+0.047*X      X=TV value

# %%
reg_model.intercept_[0]+reg_model.coef_[0][0]*150
# Out:
# 14.163089614080658

# %%
g=sns.regplot(x=X,y=y, scatter_kws={"color":"b","s":9},ci=False, color="r")
g.set_title(f"Model equation:sales={reg_model.intercept_[0]+TV*reg_model.coef_[0][0]}")
g.set_ylabel("sales")
g.set_xlabel("TV")
plt.xlim(-10,310)
plt.ylim(bottom=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-371e73ed63da> in <module>
#       1 g=sns.regplot(x=X,y=y, scatter_kws={"color":"b","s":9},ci=False, color="r")
# ----> 2 g.set_title(f"Model equation:sales={reg_model.intercept_[0]+TV*reg_model.coef_[0][0]}")
#       3 g.set_ylabel("sales")
#       4 g.set_xlabel("TV")
#       5 plt.xlim(-10,310)
#
# NameError: name 'TV' is not defined

# %%
y_pred=reg_model.predict(X)

# %%
#y_pred = y_hat

mean_squared_error(y,y_pred)
# Out:
# 10.512652915656757

# %%
#RMSE
np.sqrt(mean_squared_error(y,y_pred))
# Out:
# 3.2423221486546887

# %%
#MAE
mean_absolute_error(y,y_pred)
# Out:
# 2.549806038927486

# %% [markdown]
# **Multiple Linear Regression**

# %%
df=pd.read_csv("/content/drive/MyDrive/DATA_MINING/advertising.csv")

# %%
y=df["sales"]
X=df.drop(["sales"], axis=1)

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.20, random_state=1)

# %%
reg_model=LinearRegression().fit(X_train, y_train)

# %%
reg_model.intercept_
# Out:
# 2.907947020816433

# %%
reg_model.coef_
# Out:
# array([0.0468431 , 0.17854434, 0.00258619])

# %%
y_pred=reg_model.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.9918855518287906

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1.0402154012924718

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1.4113417558581587

# %%
# Cost function
def cost_function(Y, b, w, X):
    m = len(Y)
    sse = 0

    for i in range(0, m):
        y_hat = b + w * X[i]
        y = Y[i]
        sse += (y_hat - y) ** 2

    cost = sse /(2* m)
    return cost

# %%
# update_weights
def update_weights(Y, b, w, X, learning_rate):
    m = len(Y)
    b_deriv_sum = 0
    w_deriv_sum = 0
    for i in range(0, m):
        y_hat = b + w * X[i]
        y = Y[i]
        b_deriv_sum += (y_hat - y)
        w_deriv_sum += (y_hat - y) * X[i]
    new_b = b - (learning_rate *( 1 / m) * b_deriv_sum)
    new_w = w - (learning_rate * (1 / m )* w_deriv_sum)
    return new_b, new_w

# %%
def train(Y, initial_b, initial_w, X, learning_rate, num_iters):

    print("Starting gradient descent at b = {0}, w = {1}, cost = {2}".format(initial_b, initial_w,
                                                                   cost_function(Y, initial_b, initial_w, X)))

    b = initial_b
    w = initial_w
    cost_history = []

    for i in range(num_iters):
        b, w = update_weights(Y, b, w, X, learning_rate)
        cost = cost_function(Y, b, w, X)
        cost_history.append(cost)


        if i % 100 == 0:
            print("iter={:d}    b={:.2f}    w={:.4f}    cost={:.4}".format(i, b, w, cost))


    print("After {0} iterations b = {1}, w = {2}, cost = {3}".format(num_iters, b, w, cost_function(Y, b, w, X)))
    return cost_history, b, w

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA_MINING/advertising.csv")

X = df["radio"]
Y = df["sales"]

# hyperparameters
learning_rate = 0.001
initial_b = 0.001
initial_w = 0.001
num_iters = 10000

cost_history, b, w = train(Y, initial_b, initial_w, X, learning_rate, num_iters)
# Out:
# Starting gradient descent at b = 0.001, w = 0.001, cost = 111.47387458365004
# iter=0    b=0.01    w=0.3708    cost=26.63
# iter=100    b=0.28    w=0.4788    cost=20.8
# iter=200    b=0.54    w=0.4709    cost=20.14
# iter=300    b=0.79    w=0.4633    cost=19.52
# iter=400    b=1.03    w=0.4559    cost=18.93
# iter=500    b=1.27    w=0.4487    cost=18.38
# iter=600    b=1.49    w=0.4417    cost=17.86
# iter=700    b=1.72    w=0.4349    cost=17.36
# iter=800    b=1.93    w=0.4283    cost=16.9
# iter=900    b=2.14    w=0.4219    cost=16.46
# iter=1000    b=2.35    w=0.4157    cost=16.04
# iter=1100    b=2.54    w=0.4096    cost=15.65
# iter=1200    b=2.74    w=0.4037    cost=15.28
# iter=1300    b=2.92    w=0.3980    cost=14.93
# iter=1400    b=3.10    w=0.3925    cost=14.6
# iter=1500    b=3.28    w=0.3871    cost=14.29
# iter=1600    b=3.45    w=0.3818    cost=14.0
# iter=1700    b=3.62    w=0.3767    cost=13.72
# iter=1800    b=3.78    w=0.3718    cost=13.46
# iter=1900    b=3.94    w=0.3670    cost=13.21
# iter=2000    b=4.09    w=0.3623    cost=12.98
# iter=2100    b=4.24    w=0.3578    cost=12.76
# iter=2200    b=4.38    w=0.3534    cost=12.55
# iter=2300    b=4.52    w=0.3491    cost=12.35
# iter=2400    b=4.66    w=0.3449    cost=12.17
# iter=2500    b=4.79    w=0.3409    cost=11.99
# iter=2600    b=4.92    w=0.3369    cost=11.83
# iter=2700    b=5.04    w=0.3331    cost=11.67
# iter=2800    b=5.16    w=0.3294    cost=11.53
# iter=2900    b=5.28    w=0.3258    cost=11.39
# iter=3000    b=5.40    w=0.3223    cost=11.26
# iter=3100    b=5.51    w=0.3189    cost=11.13
# iter=3200    b=5.62    w=0.3156    cost=11.02
# iter=3300    b=5.72    w=0.3124    cost=10.91
# iter=3400    b=5.82    w=0.3093    cost=10.8
# iter=3500    b=5.92    w=0.3062    cost=10.7
# iter=3600    b=6.02    w=0.3033    cost=10.61
# iter=3700    b=6.11    w=0.3004    cost=10.52
# iter=3800    b=6.20    w=0.2976    cost=10.44
# iter=3900    b=6.29    w=0.2949    cost=10.36
# iter=4000    b=6.38    w=0.2923    cost=10.29
# iter=4100    b=6.46    w=0.2898    cost=10.22
# iter=4200    b=6.54    w=0.2873    cost=10.15
# iter=4300    b=6.62    w=0.2849    cost=10.09
# iter=4400    b=6.70    w=0.2825    cost=10.03
# iter=4500    b=6.77    w=0.2803    cost=9.977
# iter=4600    b=6.84    w=0.2780    cost=9.925
# iter=4700    b=6.91    w=0.2759    cost=9.876
# iter=4800    b=6.98    w=0.2738    cost=9.829
# iter=4900    b=7.05    w=0.2718    cost=9.786
# iter=5000    b=7.11    w=0.2698    cost=9.744
# iter=5100    b=7.17    w=0.2679    cost=9.705
# iter=5200    b=7.23    w=0.2660    cost=9.668
# iter=5300    b=7.29    w=0.2642    cost=9.633
# iter=5400    b=7.35    w=0.2625    cost=9.6
# iter=5500    b=7.41    w=0.2608    cost=9.569
# iter=5600    b=7.46    w=0.2591    cost=9.54
# iter=5700    b=7.51    w=0.2575    cost=9.512
# iter=5800    b=7.56    w=0.2560    cost=9.486
# iter=5900    b=7.61    w=0.2544    cost=9.462
# iter=6000    b=7.66    w=0.2530    cost=9.438
# iter=6100    b=7.71    w=0.2515    cost=9.416
# iter=6200    b=7.75    w=0.2501    cost=9.396
# iter=6300    b=7.80    w=0.2488    cost=9.376
# iter=6400    b=7.84    w=0.2475    cost=9.358
# iter=6500    b=7.88    w=0.2462    cost=9.34
# iter=6600    b=7.92    w=0.2450    cost=9.324
# iter=6700    b=7.96    w=0.2437    cost=9.308
# iter=6800    b=8.00    w=0.2426    cost=9.294
# iter=6900    b=8.04    w=0.2414    cost=9.28
# iter=7000    b=8.08    w=0.2403    cost=9.267
# iter=7100    b=8.11    w=0.2393    cost=9.254
# iter=7200    b=8.14    w=0.2382    cost=9.243
# iter=7300    b=8.18    w=0.2372    cost=9.232
# iter=7400    b=8.21    w=0.2362    cost=9.221
# iter=7500    b=8.24    w=0.2353    cost=9.211
# iter=7600    b=8.27    w=0.2343    cost=9.202
# iter=7700    b=8.30    w=0.2334    cost=9.193
# iter=7800    b=8.33    w=0.2325    cost=9.185
# iter=7900    b=8.36    w=0.2317    cost=9.177
# iter=8000    b=8.38    w=0.2309    cost=9.17
# iter=8100    b=8.41    w=0.2301    cost=9.163
# iter=8200    b=8.44    w=0.2293    cost=9.157
# iter=8300    b=8.46    w=0.2285    cost=9.15
# iter=8400    b=8.49    w=0.2278    cost=9.145
# iter=8500    b=8.51    w=0.2271    cost=9.139
# iter=8600    b=8.53    w=0.2264    cost=9.134
# iter=8700    b=8.55    w=0.2257    cost=9.129
# iter=8800    b=8.58    w=0.2250    cost=9.124
# iter=8900    b=8.60    w=0.2244    cost=9.12
# iter=9000    b=8.62    w=0.2238    cost=9.116
# iter=9100    b=8.64    w=0.2232    cost=9.112
# iter=9200    b=8.66    w=0.2226    cost=9.108
# iter=9300    b=8.67    w=0.2220    cost=9.105
# iter=9400    b=8.69    w=0.2214    cost=9.101
# iter=9500    b=8.71    w=0.2209    cost=9.098
# iter=9600    b=8.73    w=0.2204    cost=9.095
# iter=9700    b=8.74    w=0.2199    cost=9.093
# iter=9800    b=8.76    w=0.2194    cost=9.09
# iter=9900    b=8.78    w=0.2189    cost=9.088
# After 10000 iterations b = 8.79062282139543, w = 0.2184390657183005, cost = 9.085340487631479

# %% [markdown]
# **KNN Regressor**

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA_MINING/advertising.csv")

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
df.head(10)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   10.6

# %%
y=df["sales"]
X=df.drop(["sales"], axis=1)
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.20, random_state=1)

# %%
knn_model=KNeighborsRegressor().fit(X_train, y_train)

# %%
knn_model.n_neighbors
# Out:
# 5

# %%
knn_model.metric
# Out:
# 'minkowski'

# %%
y_pred=knn_model.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2.580140000000001

# %%
#RMSE
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1.6062814199261601

# %%
RMSE=[]

for k in range(10):
  k=k+1
  knn_model=KNeighborsRegressor(n_neighbors= k).fit(X_train,y_train)
  y_pred=knn_model.predict(X_test)
  rmse=np.sqrt(mean_squared_error(y_test,y_pred))
  RMSE.append(rmse)
  print("k=",k, "RMSE:", rmse)
# Out:
# k= 1 RMSE: 1.8617196351760381
# k= 2 RMSE: 1.3802400153596475
# k= 3 RMSE: 1.3225606476327152
# k= 4 RMSE: 1.519940377120103
# k= 5 RMSE: 1.6062814199261601
# k= 6 RMSE: 1.6890188637851926
# k= 7 RMSE: 1.6990948971107398
# k= 8 RMSE: 1.7271431433149949
# k= 9 RMSE: 1.7774548317783903
# k= 10 RMSE: 1.8807113016090484

# %%
RMSE=[]
distance=["minkowski", "euclidean", "manhattan", "hamming", "cosine"]

for i in distance:
  knn_model=KNeighborsRegressor(metric= i).fit(X_train,y_train)
  y_pred=knn_model.predict(X_test)
  rmse=np.sqrt(mean_squared_error(y_test,y_pred))
  RMSE.append(rmse)
  print("metric=",i, "RMSE:", rmse)
# Out:
# metric= minkowski RMSE: 1.6062814199261601
# metric= euclidean RMSE: 1.6062814199261601
# metric= manhattan RMSE: 1.5480536166425245
# metric= hamming RMSE: 9.74007032828819
# metric= cosine RMSE: 3.3764996668147322

# %% [markdown]
# **SVM regressor**

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA_MINING/advertising.csv")

# %%
y=df["sales"]
X=df.drop(["sales"], axis=1)
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.20, random_state=1)

# %%
from sklearn.svm import SVR

# %%
svm_model=SVR().fit(X_train,y_train)

# %%
y_pred=svm_model.predict(X_test)

# %%
#RMSE
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 1.9679208568763071
